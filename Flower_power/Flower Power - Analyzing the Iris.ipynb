# %% [markdown]
# ### the Iris Data Set by Ronald Fisher
# [data set at wikipedia](https://en.wikipedia.org/wiki/Iris_flower_data_set)

# %% [markdown]
# ### Irises - scatter plot
# Compare the sepal length and width values

# %%
from itertools import groupby
import csv
import matplotlib.pyplot as plt

input_file = 'iris.csv'
plt.figure(figsize=(7.5, 4.25))
with open(input_file, 'r') as iris_data:
    irises = list(csv.reader(iris_data))     
# Get rid of empty list at end
irises.pop()    
   
colors = {"Iris-setosa": "#2B5B84", "Iris-versicolor": "g", "Iris-virginica": "purple"}    

for species, group in groupby(irises, lambda i: i[4]):
    categorized_irises = list(group)   
    sepal_lengths = [float(iris[0]) for iris in categorized_irises]
    sepal_widths = [float(iris[1]) for iris in categorized_irises]
    plt.scatter(sepal_lengths, sepal_widths, s=10, c=colors[species], label=species)   

plt.title("Fisher's Iris Data Set", fontsize=12)
plt.xlabel("Sepal length (cm)", fontsize=10)
plt.ylabel("Sepal width (cm)", fontsize=10)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Irises - Histogram
#
# Examine the petal lengths of the various irises

# %%
import csv
import matplotlib.pyplot as plt

input_file = 'iris.csv'
plt.figure(figsize=(7.5, 4.25))
plt.style.use('classic')

with open(input_file, 'r') as iris_data:
    irises = list(csv.reader(iris_data)) 
    
virginica_petal_length = []
num_bins = 10

for petal in range(0, len(irises)-1):
    if irises[petal][4] == 'Iris-virginica':
        virginica_petal_length.append(float(irises[petal][2]))
   
plt.hist(virginica_petal_length, num_bins, facecolor='red', alpha=0.75)

plt.title('Iris-virginica Petal Length', fontsize=12)
plt.xlabel('Petal length (cm)', fontsize=10)
plt.ylabel('Probability', fontsize=10)

plt.show()

# %%
import csv
import matplotlib.pyplot as plt

input_file = 'iris.csv'
plt.figure(figsize=(7.5, 4.25))
plt.style.use('classic')

with open(input_file, 'r') as iris_data:
    irises = list(csv.reader(iris_data)) 
    
iris_setosa_petal_length = []
num_bins = 9

for petal in range(0, len(irises)-1):
    if irises[petal][4] == 'Iris-setosa':
        iris_setosa_petal_length.append(float(irises[petal][2]))
   
plt.hist(iris_setosa_petal_length, num_bins, facecolor='purple', alpha=0.75)

plt.title('Iris-setosa Petal Length', fontsize=12)
plt.xlabel('Petal length (cm)', fontsize=10)
plt.ylabel('Probability', fontsize=10)

plt.show()

# %%
import csv
import matplotlib.pyplot as plt

input_file = 'iris.csv'
plt.figure(figsize=(7.5, 4.25))
plt.style.use('classic')

with open(input_file, 'r') as iris_data:
    irises = list(csv.reader(iris_data)) 
    
iris_versicolor_petal_length = []
num_bins = 12

for petal in range(0, len(irises)-1):
    if irises[petal][4] == 'Iris-versicolor':
        iris_versicolor_petal_length.append(float(irises[petal][2]))
   
plt.hist(iris_versicolor_petal_length, num_bins, facecolor='yellow', alpha=0.75)

plt.title('Iris-versicolor Petal Length', fontsize=12)
plt.xlabel('Petal length (cm)', fontsize=10)
plt.ylabel('Probability', fontsize=10)

plt.show()

# %% [markdown]
# ### Irises - Box plots
#
# Examine the petal lengths of the various irises

# %%
from itertools import groupby
import csv
import matplotlib.pyplot as plt

input_file = 'iris.csv'
plt.figure(figsize=(7.5, 4.25))
plt.style.use('classic')

fig = plt.figure()

with open(input_file, 'r') as iris_data:
    irises = list(csv.reader(iris_data)) 
irises.pop()    

petal_lengths = []

for species, group in groupby(irises, lambda i: i[4]):
    petal_lengths.append([float(petal[2]) for petal in group])
    
plt.boxplot(petal_lengths)
plt.axis([0,4,0,8])
plt.xticks([1,2,3], ['Setosa', 'Versicolor', 'Virginica'])
plt.title("Fisher's Iris Data Set: Petal Length", fontsize=12, loc="left")
plt.xlabel("Iris Varity", fontsize=10)
plt.ylabel("Petal Length (cm)", fontsize=10)

fig.savefig('petal_length_boxplot.png')

plt.show()

# %% [markdown]
# #### Supported file types for exporting graphs
# file types a.k.a hard copy / non-interactive backends

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
print(fig.canvas.get_supported_filetypes())
# Out:
# {'ps': 'Postscript', 'eps': 'Encapsulated Postscript', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format'}
